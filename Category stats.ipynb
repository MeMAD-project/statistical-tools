# %%
# Auto-reload modules when accessing them:
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings("ignore", message="numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88")
import argparse
from collections import namedtuple, Counter
from categories import Categories
import sys
import pickle
from nltk.corpus import wordnet as wn
from pprint import pprint
import analysis_funs as va
import pandas as pd
import pandas as pd
from tqdm._tqdm_notebook import tqdm_notebook
tqdm_notebook.pandas()
# Echo all output:
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from os.path import dirname
sys.path.append('/home/polisa1/scratchdir/dataset-analytics')
import category_matcher as cm
# %cd /scratch/cs/imagedb/picsom/databases/visualgenome/analysis/arturs/region_descriptions
# Out:
# /scratch/cs/imagedb/picsom/databases/visualgenome/analysis/arturs/region_descriptions

# %%
vg_regions = pd.read_feather('pickles/vg_region_descriptions.feather', nthreads=4)
# Out:
# /share/apps2/anaconda/anaconda3/latest/lib/python3.6/site-packages/pandas/io/feather_format.py:112: FutureWarning: `nthreads` argument is deprecated, pass `use_threads` instead
#   return feather.read_dataframe(path, nthreads=nthreads)

# %%
coco2014 = pd.read_feather('pickles/coco_captions_train2014.feather', nthreads=4)
# Out:
# /share/apps2/anaconda/anaconda3/latest/lib/python3.6/site-packages/pandas/io/feather_format.py:112: FutureWarning: `nthreads` argument is deprecated, pass `use_threads` instead
#   return feather.read_dataframe(path, nthreads=nthreads)

# %%
vg_regions
# Out:
#          height  image_id                                          phrase  \
# 0           139         1                    the clock is green in colour
# 1           109         1                      shade is along the street
# 2            30         1                         man is wearing sneakers
# 3            36         1                         cars headlights are off
# 4            49         1                bikes are parked at the far edge
# 5           178         1            A sign on the facade of the building
# 6           332         1                    A tree trunk on the sidewalk
# 7           270         1                            A man in a red shirt
# 8           100         1              A brick sidewalk beside the street
# 9           179         1                         The back of a white car
# 10          266         1                        a man is wearing glasses
# 11          174         1              a parking meter is on the sidewalk
# 12           56         1                  bicycles are in the background
# 13          272         1                          a man wears grey shoes
# 14          259         1                       a man has brown shoes on
# 15          276         1  A man dressed in a red shirt and black pants.
# 16          240         1    A man wearing a gray jacket and gray pants.
# 17           48         1               A bicycle parked on the sidewalk.
# 18          187         1       A white work truck parked on the street.
# 19          154         1              A white car parked on the street.
# 20          274         1                         guy wearing a red shirt
# 21          192         1                 black sign on front of building
# 22           48         1                        bicycles on the sidewalk
# 23          161         1                   parking meter on the sidewalk
# 24          257         1                    guy holding hand to his chin
# 25          154         1                         he has an orange tshirt
# 26           18         1                              he has brown shoes
# 27          168         1                               it is a white van
# 28           34         1                          he has raised his chin
# 29           28         1                 it is a wall made of grey tiles
# ...         ...       ...                                             ...
# 5408659      37   2417997                         blue sky with no clouds
# 5408660     182   2417997                                a dark green bus
# 5408661      15   2417997                     a bus front right headlight
# 5408662      13   2417997                      a bus front left headlight
# 5408663      45   2417997                          a bus front windshield
# 5408664      40   2417997                   a mountain range in distance
# 5408665      12   2417997                          a yellow license plate
# 5408666      36   2417997                           a bus radiator grille
# 5408667      25   2417997                                 a body of water
# 5408668     178   2417997                                a clear blue sky
# 5408669     128   2417997                                  open bus doors
# 5408670     180   2417997                    A green bus on a dirt field.
# 5408671     182   2417997                          A green bus on a road.
# 5408672      45   2417997                          A windshield on a bus.
# 5408673      37   2417997                  A grill on the front of a bus.
# 5408674      18   2417997                              A number on a bus.
# 5408675      15   2417997                       A license plate on a bus.
# 5408676      40   2417997            A large snow covered mountain range.
# 5408677     106   2417997                            A side loading door.
# 5408678     176   2417997                  A large green bus in a desert.
# 5408679     182   2417997                       A crystal clear blue sky.
# 5408680     133   2417997                             a green bus on road
# 5408681     172   2417997                           a green bus on street
# 5408682      92   2417997                           a bus with doors open
# 5408683     127   2417997                      a green bus with door open
# 5408684     181   2417997        A green school bus traveling down a road
# 5408685      15   2417997                   Numbers on the front of a bus
# 5408686      13   2417997                 A yellow license plate on a bus
# 5408687     112   2417997            A country road between two mountains
# 5408688     177   2417997                                the bus is green
#
#          region_id  width    x    y
# 0             1382     82  421   57
# 1             1383    182  194  372
# 2             1384     61  241  491
# 3             1385     36  617  377
# 4             1386     41  322  298
# 5             1432     84  122   14
# 6             1433     96  624  236
# 7             1434     69  238  247
# 8             1435    451  150  495
# 9             1436     82  711  345
# 10            1482     84  225  243
# 11            1483     32  576  308
# 12            1484     42  320  301
# 13            1485     67  235  244
# 14            1486     77  378  270
# 15            1532     54  247  256
# 16            1533     65  383  272
# 17            1534     34  325  320
# 18            1535    252  541  277
# 19            1536     37  758  348
# 20            1582     68  236  248
# 21            1583     80  124    7
# 22            1584     49  317  310
# 23            1585     30  575  312
# 24            1586     86  367  263
# 25            1632     85  238  251
# 26            1633     68  375  486
# 27            1634    203  533  257
# 28            1635     72  377  257
# 29            1636     93    8  192
# ...            ...    ...  ...  ...
# 5408659    4931321     65   73   49
# 5408660    4931322    284   16  112
# 5408661    4931323     35  198  216
# 5408662    4931324      7  293  219
# 5408663    4931325     85  164  133
# 5408664    4931326    246  253  157
# 5408665    4931327     14  261  248
# 5408666    4931328     55  235  196
# 5408667    4931329    197  302  209
# 5408668    4931330    498    1    1
# 5408669    4931331     48   98  132
# 5408670    4931332    287   11  110
# 5408671    4931333    287   14  112
# 5408672    4931334     84  166  133
# 5408673    4931335     60  230  193
# 5408674    4931336     31  190  229
# 5408675    4931337     19  259  248
# 5408676    4931338    247  249  160
# 5408677    4931339     34  119  130
# 5408678    4931340    285   14  114
# 5408679    4931341    495    0    0
# 5408680    4931342    141  146  113
# 5408681    4931343    147  105  120
# 5408682    4931344     57  114  124
# 5408683    4931345     67  103  124
# 5408684    5516956    303    0  111
# 5408685    5516957     23  191  231
# 5408686    5516958     17  259  247
# 5408687    5516959    317  180  218
# 5408688    5516970    283   15  112
#
# [5408689 rows x 7 columns]
